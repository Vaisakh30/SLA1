# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaisakh30/SLA1/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CLEANING THE DATA FOR PROPER ANALYSIS

# %% [markdown]
# # New Section

# %%
import pandas as pd

# %%
df = pd.read_csv ('world_marathon_majors.csv', encoding='latin1')

# %% [markdown]
# CHANGE THE FONT STYLE TO NORMAL

# %%
df.style.set_table_styles([{
    'selector': 'td',
    'props': [('font-family', 'Arial'), ('font-size', '12pt')]
}]).set_caption('World Marathon Majors Data')
# Out:
# <style type="text/css">
# #T_66212 td {
#   font-family: Arial;
#   font-size: 12pt;
# }
# </style>
# <table id="T_66212" class="dataframe">
#   <caption>World Marathon Majors Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66212_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_66212_level0_col1" class="col_heading level0 col1" >winner</th>
#       <th id="T_66212_level0_col2" class="col_heading level0 col2" >gender</th>
#       <th id="T_66212_level0_col3" class="col_heading level0 col3" >country</th>
#       <th id="T_66212_level0_col4" class="col_heading level0 col4" >marathon</th>
#       <th id="T_66212_level0_col5" class="col_heading level0 col5" >time</th>
#       <th id="T_66212_level0_col6" class="col_heading level0 col6" >Unnamed: 6</th>
#       <th id="T_66212_level0_col7" class="col_heading level0 col7" >Unnamed: 7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
print (df.head())
# Out:
#    year              winner  gender   country marathon      time  Unnamed: 6  \
# 0  2018      Dickson Chumba    Male     Kenya    Tokyo  02:05:30         NaN
# 1  2018      Birhane Dibaba  Female  Ethiopia    Tokyo  02:19:51         NaN
# 2  2017      Wilson Kipsang    Male     Kenya    Tokyo  02:03:58         NaN
# 3  2017  Sarah Chepchirchir  Female     Kenya    Tokyo  02:19:47         NaN
# 4  2016       Feyisa Lilesa    Male  Ethiopia    Tokyo  02:06:56         NaN
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# INSPECTING DATA

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        536 non-null    int64
#  1   winner      536 non-null    object
#  2   gender      536 non-null    object
#  3   country     536 non-null    object
#  4   marathon    536 non-null    object
#  5   time        536 non-null    object
#  6   Unnamed: 6  0 non-null      float64
#  7   Unnamed: 7  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.6+ KB
# None

# %%
print (df.describe())
# Out:
#               year  Unnamed: 6  Unnamed: 7
# count   536.000000         0.0         0.0
# mean   1987.919776         NaN         NaN
# std      26.104662         NaN         NaN
# min    1897.000000         NaN         NaN
# 25%    1980.000000         NaN         NaN
# 50%    1993.000000         NaN         NaN
# 75%    2007.000000         NaN         NaN
# max    2018.000000         NaN         NaN

# %% [markdown]
# Indentify missin

# %%
print(df.isnull().sum())
# Out:
# year            0
# winner          0
# gender          0
# country         0
# marathon        0
# time            0
# Unnamed: 6    536
# Unnamed: 7    536
# dtype: int64

# %% [markdown]
# IDENTIFYING DUPLICATES AND REMOVING

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.head()
# Out:
#    year              winner  gender   country marathon      time  Unnamed: 6  \
# 0  2018      Dickson Chumba    Male     Kenya    Tokyo  02:05:30         NaN
# 1  2018      Birhane Dibaba  Female  Ethiopia    Tokyo  02:19:51         NaN
# 2  2017      Wilson Kipsang    Male     Kenya    Tokyo  02:03:58         NaN
# 3  2017  Sarah Chepchirchir  Female     Kenya    Tokyo  02:19:47         NaN
# 4  2016       Feyisa Lilesa    Male  Ethiopia    Tokyo  02:06:56         NaN
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# CONVERTING TO CSV FILE

# %%
df.to_csv('final2_world_marathon_majors.csv',index=False)
